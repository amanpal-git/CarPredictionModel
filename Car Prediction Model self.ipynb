# %%
import pandas as pd
import numpy as np

# %%
car= pd.read_csv('Cleaned car.csv')

# %%
car
# Out:
#      Unnamed: 0                    name   company  year   Price  kms_driven  \
# 0             0     Hyundai Santro Xing   Hyundai  2007   80000       45000
# 1             1     Mahindra Jeep CL550  Mahindra  2006  425000          40
# 2             2       Hyundai Grand i10   Hyundai  2014  325000       28000
# 3             3  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4             4               Ford Figo      Ford  2012  175000       41000
# ..          ...                     ...       ...   ...     ...         ...
# 810         810      Maruti Suzuki Ritz    Maruti  2011  270000       50000
# 811         811          Tata Indica V2      Tata  2009  110000       30000
# 812         812    Toyota Corolla Altis    Toyota  2009  300000      132000
# 813         813            Tata Zest XM      Tata  2018  260000       27000
# 814         814      Mahindra Quanto C8  Mahindra  2013  390000       40000
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
X = car[['name','company','year','kms_driven','fuel_type']]
y = car['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
categorical_features = ['name','company','fuel_type']
numeric_features = ['year','kms_driven']

# %%
ohe = OneHotEncoder()
ohe.fit(X[['name', 'company', 'fuel_type']])
# Out:
# OneHotEncoder()

# %%
ohe.categories_
# Out:
# [array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#         'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#         'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#         'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#         'Chevrolet Beat LS', 'Chevrolet Beat LT', 'Chevrolet Beat PS',
#         'Chevrolet Cruze LTZ', 'Chevrolet Enjoy', 'Chevrolet Enjoy 1.4',
#         'Chevrolet Sail 1.2', 'Chevrolet Sail UVA', 'Chevrolet Spark',
#         'Chevrolet Spark 1.0', 'Chevrolet Spark LS', 'Chevrolet Spark LT',
#         'Chevrolet Tavera LS', 'Chevrolet Tavera Neo', 'Datsun GO T',
#         'Datsun Go Plus', 'Datsun Redi GO', 'Fiat Linea Emotion',
#         'Fiat Petra ELX', 'Fiat Punto Emotion', 'Force Motors Force',
#         'Force Motors One', 'Ford EcoSport', 'Ford EcoSport Ambiente',
#         'Ford EcoSport Titanium', 'Ford EcoSport Trend',
# ...

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('dog', OneHotEncoder(categories=ohe.categories_), categorical_features)
    ],
    remainder='passthrough'
)

# %%
pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('model', LinearRegression())])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('dog',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#        'Chevro...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
# ...

# %%
y_pred = pipeline.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 41962549006.67784

# %%
r2_score(y_test, y_pred)
# Out:
# 0.6007300777581726

# %%
scores=[]
for i in range(1000):
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1,random_state=i)
    lr = LinearRegression()
    pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('model', lr)])
    pipeline.fit(X_train,y_train)
    y_pred = pipeline.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 302

# %%
scores[np.argmax(scores)]
# Out:
# 0.8991116065992623

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1,random_state=np.argmax(scores))
# lr = LinearRegression()
pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('model', lr)])
pipeline.fit(X_train,y_train)
y_pred = pipeline.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.8991116065992623

# %%
new_data = pd.DataFrame([['Mahindra XUV500','Mahindra',2016,4000,'Petrol']], columns=['name','company','year','kms_driven','fuel_type'])

# %%
predictions = pipeline.predict(new_data)

# %%
print(predictions)
# Out:
# [750744.89324179]

# %%
pipeline.predict(pd.DataFrame([['Mahindra XUV500','Mahindra',2016,4000,'Petrol']], columns=['name','company','year','kms_driven','fuel_type']))
# Out:
# array([750744.89324179])

# %%
result = pipeline.predict(pd.DataFrame([['Hyundai Santro Xing','Hyundai',2024,4000,'Petrol']], columns=['name','company','year','kms_driven','fuel_type']))

# %%
print(type(result))
# Out:
# <class 'numpy.ndarray'>

# %%
import pickle

# %%
with open("model.pkl", "wb") as model_file:
    pickle.dump(pipeline, model_file)
